# %% [markdown]
# <a href="https://colab.research.google.com/github/va11h411a/Jobsheet-AI-course/blob/main/Jobsheet%204%20Pandas%20librarry.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv ('/content/data.csv')
print(df.to_string())

df
pd.options.display.max_rows
pd.options.display.max_rows = 9999

df = pd.read_csv ('/content/data.csv')
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
#Membaca Json
import pandas as pd

df = pd.read_json('/content/data.json')
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.5
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
#Menggunakan parameter
import pandas as pd

df = pd.read_csv('/content/data.csv', sep=',', header=0)
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
#membaca costum data
import pandas as pd

data = {
    "Duration":{
      "0":60,
      "1":60,
      "2":60,
      "3":45
    },
    "Pulse":{
      "0":110,
      "1":117,
      "2":103,
      "3":109
    },
    "Maxpulse":{
      "0":130,
      "1":145,
      "2":135,
      "3":175
    },
    "Calories":{
    "0":409,
    "1":479,
    "2":340,
    "3":282
  }
}

df = pd.DataFrame(data)
print(df)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282

# %%
#membuat dan mengakses elemen series

import pandas as pd

li = [1, 7, 2]
se = pd.Series(li)

print(se)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
#mengakses elemen series
import pandas as pd

li = [1, 7, 2]
se = pd.Series(li)

print(se[0])
# Out:
# 1

# %%
#memberikan label pada series
import pandas as pd

li = [1, 7, 2]
se = pd.Series(li, index = ['x', 'y', 'z'])

print(se['x'])
# Out:
# 1

# %%
#membuat series dari dictionary
import pandas as pd

calories = {"day1": 420, "day2": 380, "day3": 390}
se = pd.Series(calories)

print(se)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
#membuat dataframe
import pandas as pd

df = pd.DataFrame(data = {"Nama": ["Ali", "Pakas", "Deka"],
                          "Umur": [15, 16, 17],
                          "Kelas": [8, 9, 10]})
df.columns
df.columns.values[0] = "Nama Singkat"
df

data = {
  "calories": [420, 380, 390],
    "duration": [50, 40, 45]
}

df = pd.DataFrame(data)
df
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
#Mengakses elemen pada dataframe


df.iloc[0:2, [0,1]]
df.iloc[0:2, 0:2]
df.iloc[:, 0:2]
df.loc[0:2, :'calories']
df.loc[0:2, ['calories', 'duration']]
df['calories']
df['calories'][0]
df[['calories']]
df[['calories']].loc[[0, 1]]
# Out:
#    calories
# 0       420
# 1       380

# %%
#Memberi nama pada index
data = {
    "calories": [420, 380, 390],
    "duration": [50, 40, 45]
}

df = pd.DataFrame(data, index = ["day1", "day2", "day3"])
print(df)
df
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %%
#melihat DataFrame
import pandas as pd

df = pd.read_csv('/content/data.csv')
df
df.head()
df.tail()
df.head(10)
df.shape
df.dtypes
# Out:
# Duration      int64
# Pulse         int64
# Maxpulse      int64
# Calories    float64
# dtype: object

# %%
#Membaca informasi pada DataFrame #1

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522 entries, 0 to 521
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            522 non-null    int64
#  1   player_name   522 non-null    object
#  2   games         522 non-null    int64
#  3   time          522 non-null    int64
#  4   goals         522 non-null    int64
#  5   xG            522 non-null    float64
#  6   assists       522 non-null    int64
#  7   xA            522 non-null    float64
#  8   shots         522 non-null    int64
#  9   key_passes    522 non-null    int64
#  10  yellow_cards  522 non-null    int64
#  11  red_cards     522 non-null    int64
#  12  position      522 non-null    object
#  13  team_title    522 non-null    object
#  14  npg           522 non-null    int64
#  15  npxG          522 non-null    float64
#  16  xGChain       522 non-null    float64
#  17  xGBuildup     522 non-null    float64
# ...

# %%
#Membaca informasi pada DataFrame #2

df.describe()
# Out:
#                 id       games         time       goals          xG  \
# count   522.000000  522.000000   522.000000  522.000000  522.000000
# mean   4380.932950   19.643678  1420.068966    1.862069    2.000806
# std    3281.776121   11.619836  1031.604819    3.338851    3.317946
# min      65.000000    1.000000     1.000000    0.000000    0.000000
# 25%     839.750000   10.000000   470.250000    0.000000    0.074668
# 50%    4627.000000   21.000000  1342.000000    1.000000    0.737295
# 75%    7690.500000   30.000000  2319.000000    2.000000    2.053378
# max    9552.000000   38.000000  3420.000000   23.000000   22.174859
#
#           assists          xA       shots  key_passes  yellow_cards  \
# count  522.000000  522.000000  522.000000  522.000000    522.000000
# mean     1.289272    1.376029   17.379310   12.963602      2.061303
# std      2.083350    1.886510   21.572664   16.164361      2.203661
# min      0.000000    0.000000    0.000000    0.000000      0.000000
# ...

# %%
#Membaca informasi pada DataFrame #3

df['calories'].mean(), df['calories'].median(), df['calories'].mode()[0]
# Out:
# (np.float64(396.6666666666667), 390.0, np.int64(380))

# %%
#Membaca informasi pada DataFrame #4

df.corr()
# Out:
#           calories  duration
# calories  1.000000  0.960769
# duration  0.960769  1.000000

# %%
#Tugas praktikum - 1
import pandas as pd

df = pd.read_csv('/content/epl-goalScorer(20-21).csv')
print(df.to_string())
# Out:
#      Unnamed: 0    id                player_name  games  time  goals         xG  assists         xA  shots  key_passes  yellow_cards  red_cards position                     team_title  npg       npxG    xGChain  xGBuildup
# 0             0   647                 Harry Kane     35  3097     23  22.174859       14   7.577094    138          49             1          0        F                      Tottenham   19  19.130183  24.995648   4.451257
# 1             1  1250              Mohamed Salah     37  3085     22  20.250847        5   6.528526    126          55             0          0    F M S                      Liverpool   16  15.683834  28.968234   9.800236
# 2             2  1228            Bruno Fernandes     37  3117     18  16.019454       12  11.474996    121          95             6          0      M S              Manchester United    9   8.407840  26.911412  11.932285
# ...

# %%
import pandas as pd

# Load the data and drop the 'Unnamed: 0' column
df = pd.read_csv('/content/epl-goalScorer(20-21).csv')

# Drop the 'Unnamed: 0' column if it exists
df.drop(columns=['Unnamed: 0'], inplace=True)

# Display the first 5 rows
first_five_rows = df.head(5)
print(first_five_rows)
# Out:
#      id      player_name  games  time  goals         xG  assists         xA  \
# 0   647       Harry Kane     35  3097     23  22.174859       14   7.577094
# 1  1250    Mohamed Salah     37  3085     22  20.250847        5   6.528526
# 2  1228  Bruno Fernandes     37  3117     18  16.019454       12  11.474996
# 3   453    Son Heung-Min     37  3139     17  11.023287       10   9.512992
# 4   822  Patrick Bamford     38  3085     17  18.401863        7   3.782247
#
#    shots  key_passes  yellow_cards  red_cards position         team_title  \
# 0    138          49             1          0        F          Tottenham
# 1    126          55             0          0    F M S          Liverpool
# 2    121          95             6          0      M S  Manchester United
# 3     68          75             0          0    F M S          Tottenham
# 4    107          30             3          0      F S              Leeds
#
#    npg       npxG    xGChain  xGBuildup
# ...

# %%
#Tugas Praktikum - 3
import pandas as pd

# Load the CSV file
df = pd.read_csv('/content/epl-goalScorer(20-21).csv')

# Drop the 'Unnamed: 0' column if it exists
df.drop(columns=['Unnamed: 0'], inplace=True)

# Get the number of rows and columns
rows, columns = df.shape

# Print the result
print(f"Number of rows: {rows}")
print(f"Number of columns: {columns}")
# Out:
# Number of rows: 522
# Number of columns: 18

# %%
#Tugas Praktikum - 4
import pandas as pd

df = pd.read_csv('/content/epl-goalScorer(20-21).csv')
print(df.dtypes)

data_types_count = df.dtypes.value_counts()
print(data_types_count)
# Out:
# Unnamed: 0        int64
# id                int64
# player_name      object
# games             int64
# time              int64
# goals             int64
# xG              float64
# assists           int64
# xA              float64
# shots             int64
# key_passes        int64
# yellow_cards      int64
# red_cards         int64
# position         object
# team_title       object
# npg               int64
# npxG            float64
# xGChain         float64
# xGBuildup       float64
# dtype: object
# int64      11
# float64     5
# object      3
# Name: count, dtype: int64

# %%
#Tugas Praktikum - 5

import pandas as pd

# Load the dataset
df = pd.read_csv('/content/epl-goalScorer(20-21).csv')

# Drop the 'Unnamed: 0' column if it exists
df.drop(columns=['Unnamed: 0'], inplace=True)

# 5. Display the total number of goals scored by each player
goals_per_player = df[['player_name', 'goals']].groupby('player_name').sum()
print("Jumlah goal yang dicetak setiap pemain:")
print(goals_per_player)
# Out:
# Jumlah goal yang dicetak setiap pemain:
#                            goals
# player_name
# Aaron Connolly                 2
# Aaron Cresswell                0
# Aaron Ramsdale                 0
# Aaron Wan-Bissaka              2
# Abdoulaye Doucouré             2
# Aboubakar Kamara               0
# Adam Lallana                   1
# Adam Webster                   1
# Adama Traoré                   2
# Ademola Lookman                4
# Adrián                         0
# Ahmed Elmohamady               0
# Ahmed Hegazy                   0
# Ainsley Maitland-Niles         0
# Aleksandar Mitrovic            3
# Alex Iwobi                     1
# Alex McCarthy                  0
# Alex Oxlade-Chamberlain        1
# Alex Telles                    0
# Alexandre Jankewitz            0
# Alexandre Lacazette           13
# Alexis Mac Allister            1
# Alireza Jahanbakhsh            0
# Alisson                        1
# Allan                          0
# ...

# %%
#Tugas Praktikum - 6
# 6. Display a DataFrame consisting of player name, goals, position, team name, and yellow cards
player_stats = df[['player_name', 'goals', 'position', 'team_title', 'yellow_cards']]
print("\nDataFrame pemain dengan nama, goal, posisi, klub, dan jumlah kartu kuning:")
print(player_stats)
# Out:
# DataFrame pemain dengan nama, goal, posisi, klub, dan jumlah kartu kuning:
#                    player_name  goals position                     team_title  \
# 0                   Harry Kane     23        F                      Tottenham
# 1                Mohamed Salah     22    F M S                      Liverpool
# 2              Bruno Fernandes     18      M S              Manchester United
# 3                Son Heung-Min     17    F M S                      Tottenham
# 4              Patrick Bamford     17      F S                          Leeds
# 5        Dominic Calvert-Lewin     16      F S                        Everton
# 6                  Jamie Vardy     15      F S                      Leicester
# 7                Ollie Watkins     14        F                    Aston Villa
# 8               Ilkay Gündogan     13      M S                Manchester City
# 9          Alexandre Lacazette     13    F M S                        Arsenal
# ...

# %%
#Tugas Praktikum - 7
# 7. Display all players from the "Liverpool" club
liverpool_players = df[df['team_title'] == 'Liverpool']
print("\nPemain dari klub 'Liverpool':")
print(liverpool_players[['player_name', 'team_title']])
# Out:
# Pemain dari klub 'Liverpool':
#                  player_name team_title
# 1              Mohamed Salah  Liverpool
# 16                Sadio Mané  Liverpool
# 26           Roberto Firmino  Liverpool
# 30                Diogo Jota  Liverpool
# 116      Georginio Wijnaldum  Liverpool
# 130   Trent Alexander-Arnold  Liverpool
# 161         Thiago Alcántara  Liverpool
# 162               Joel Matip  Liverpool
# 172         Jordan Henderson  Liverpool
# 187          Virgil van Dijk  Liverpool
# 192  Alex Oxlade-Chamberlain  Liverpool
# 198                  Alisson  Liverpool
# 204         Andrew Robertson  Liverpool
# 226             Curtis Jones  Liverpool
# 251       Nathaniel Phillips  Liverpool
# 272             Divock Origi  Liverpool
# 274             James Milner  Liverpool
# 278                   Adrián  Liverpool
# 330          Xherdan Shaqiri  Liverpool
# 335             Joseph Gomez  Liverpool
# 375                  Fabinho  Liverpool
# 384               Naby Keita  Liverpool
# ...

# %%
#Tugas Praktikum - 8
# 8. Display all players from the "Arsenal" club
arsenal_players = df[df['team_title'] == 'Arsenal']
print("\nPemain dari klub 'Arsenal':")
print(arsenal_players[['player_name', 'team_title']])
# Out:
# Pemain dari klub 'Arsenal':
#                    player_name team_title
# 9          Alexandre Lacazette    Arsenal
# 19   Pierre-Emerick Aubameyang    Arsenal
# 36                Nicolas Pepe    Arsenal
# 65                 Bukayo Saka    Arsenal
# 140                    Gabriel    Arsenal
# 146              Eddie Nketiah    Arsenal
# 149           Emile Smith-Rowe    Arsenal
# 152         Gabriel Martinelli    Arsenal
# 160               Granit Xhaka    Arsenal
# 164            Héctor Bellerín    Arsenal
# 165             Mohamed Elneny    Arsenal
# 180                    Willian    Arsenal
# 203                 David Luiz    Arsenal
# 209            Martin Odegaard    Arsenal
# 248             Kieran Tierney    Arsenal
# 267                 Bernd Leno    Arsenal
# 269             Sead Kolasinac    Arsenal
# 275             Calum Chambers    Arsenal
# 322              Cédric Soares    Arsenal
# 348           Shkodran Mustafi    Arsenal
# 354                Rob Holding    Arsenal
# ...

# %%
#Tugas Praktikum - 9
# 9. Display the top 10 players with the most yellow cards
top_yellow_cards = df[['player_name', 'yellow_cards']].sort_values(by='yellow_cards', ascending=False).head(10)
print("\n10 pemain dengan jumlah kartu kuning terbanyak:")
print(top_yellow_cards)
# Out:
# 10 pemain dengan jumlah kartu kuning terbanyak:
#                player_name  yellow_cards
# 106            John McGinn            12
# 157        Conor Gallagher            11
# 125          Harry Maguire            11
# 259        Kalvin Phillips            10
# 110  Pierre-Emile Højbjerg             9
# 216       Luka Milivojevic             8
# 397           Isaac Hayden             8
# 218          Yves Bissouma             8
# 448         John Lundstram             8
# 399           Douglas Luiz             8

# %%
#Tugas Praktikum - 10
# 10. Display the top 10 players with the most red cards
top_red_cards = df[['player_name', 'red_cards']].sort_values(by='red_cards', ascending=False).head(10)
print("\n10 pemain dengan jumlah kartu merah terbanyak:")
print(top_red_cards)
# Out:
# 10 pemain dengan jumlah kartu merah terbanyak:
#              player_name  red_cards
# 61            Lewis Dunk          2
# 488         Matthew Cash          1
# 493     Antonee Robinson          1
# 21     Christian Benteke          1
# 18       Matheus Pereira          1
# 476  Alexandre Jankewitz          1
# 25          Tomas Soucek          1
# 443            John Egan          1
# 433            Ben White          1
# 421         Matt Doherty          1
